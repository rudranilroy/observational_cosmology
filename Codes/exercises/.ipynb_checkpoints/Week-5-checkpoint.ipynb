# %% [markdown]
# # Import the packages

# %%
import pandas as pd
import numpy as np
from scipy.integrate import quad
import scipy.linalg as la
import matplotlib.pyplot as plt
import emcee
import corner
import os
import time
from multiprocess import Pool, cpu_count

# %% [markdown]
# # Load the Dataset and Covariance Matrix

# %%
# Load the main dataset
data_file_path = '../../data/Pantheon+SH0ES.dat'
try:
    df = pd.read_csv(data_file_path, sep=r'\s+')
    N_data = len(df)
    print(f"Dataset loaded successfully. Total supernovae: {N_data}")
except FileNotFoundError:
    print(f"Error: The file {data_file_path} was not found.")

# Load and prepare the Covariance Matrix
cov_file_path = '../../data/Pantheon+SH0ES_STAT+SYS.cov' 
try:
    with open(cov_file_path, 'r') as f:
        lines = f.readlines()
    if len(lines[0].split()) == 1:
        lines = lines[1:]
        
    cov_1d = np.loadtxt(lines)
    C = cov_1d.reshape((N_data, N_data))
    
    # Cholesky decomposition for safe inversion and log-determinant
    c_chol, lower = la.cho_factor(C)
    C_inv = la.cho_solve((c_chol, lower), np.eye(N_data))
    log_det_C = 2.0 * np.sum(np.log(np.diag(c_chol)))
    
    print("Covariance matrix loaded, inverted, and log-determinant calculated.")
except FileNotFoundError:
    print(f"Error: The file {cov_file_path} was not found.")
# Out:
# Dataset loaded successfully. Total supernovae: 1701
# Covariance matrix loaded, inverted, and log-determinant calculated.

# %% [markdown]
# # Define Physics Model

# %%
c = 299792.458 # Speed of light in km/s

def model_calibrators(M_B, mu_ceph):
    return M_B + mu_ceph

def E_inverse(z, Omega_m):
    Omega_L = 1.0 - Omega_m
    return 1.0 / np.sqrt(Omega_m * (1 + z)**3 + Omega_L)

def luminosity_distance_mpc(z_hel, z_cmb, H_0, Omega_m):
    integral, _ = quad(E_inverse, 0, z_cmb, args=(Omega_m,))
    return (c / H_0) * (1 + z_hel) * integral

def model_cosmology(z_hel, z_cmb, M_B, H_0, Omega_m):
    d_L_mpc = luminosity_distance_mpc(z_hel, z_cmb, H_0, Omega_m)
    mu_lcdm = 5.0 * np.log10(d_L_mpc) + 25.0
    return M_B + mu_lcdm

# %% [markdown]
# # Define the Bayesian Framework (Prior, Likelihood, Posterior)

# %%
def build_residual_vector(params, data):
    Omega_m, H_0, M_B = params
    delta = np.zeros(len(data))
    
    for i, row in data.iterrows():
        m_b_obs = row['m_b_corr']
        if row['IS_CALIBRATOR'] == 1 and row['CEPH_DIST'] > -9:
            m_b_th = model_calibrators(M_B, row['CEPH_DIST'])
        else:
            m_b_th = model_cosmology(row['zHEL'], row['zCMB'], M_B, H_0, Omega_m)
        delta[i] = m_b_obs - m_b_th
    return delta

def log_likelihood(params, data, C_inv, log_det_C):
    """Computes the true ln(L) for MCMC (not negative)"""
    delta = build_residual_vector(params, data)
    chi2 = np.dot(delta.T, np.dot(C_inv, delta))
    N_obs = len(data)
    ln_L = -0.5 * (chi2 + log_det_C + N_obs * np.log(2 * np.pi))
    return ln_L

def log_prior(params):
    Omega_m, H_0, M_B = params
    if (0.01 < Omega_m < 0.99) and (50.0 < H_0 < 100.0) and (-21.0 < M_B < -18.0):
        return 0.0 # log(1) = 0 for uniform prior
    return -np.inf # log(0) = -inf for regions outside the prior

def log_posterior(params, data, C_inv, log_det_C):
    """ ln P(theta | data) = ln prior(theta) + ln L(data | theta) """
    lp = log_prior(params)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(params, data, C_inv, log_det_C)

# %% [markdown]
# # Run the MCMC Chain

# %%
os.environ["OMP_NUM_THREADS"] = "1"

if __name__ == '__main__':
    print("Initializing MCMC Walkers...")
    
    # Dimensionality of the parameter space (Omega_m, H_0, M_B)
    ndim = 3 
    
    # Number of MCMC walkers (Best practice: make this a multiple of your CPU cores)
    nwalkers = 15 
    
    # Initialize walkers around the best-fit values from Week 4
    best_fit_guess = np.array([0.33, 73.0, -19.24])
    initial_pos = best_fit_guess + 1e-4 * np.random.randn(nwalkers, ndim)
    
    # Set up the backend to save the chain to disk safely
    filename = "mcmc_chains/pantheon_mcmc_chain.h5"
    backend = emcee.backends.HDFBackend(filename)
    backend.reset(nwalkers, ndim)
    
    nsteps = 1000
    ncpu = max(1, cpu_count() - 2)
 
    print(f"Detected {cpu_count()} CPU cores. Setting up parallel pool...")
    
    # Use a multiprocessing Pool context manager
    start_time = time.time()
    with Pool(processes=ncpu) as pool:
        # Initialize the emcee EnsembleSampler with the pool argument
        sampler = emcee.EnsembleSampler(
            nwalkers, 
            ndim, 
            log_posterior, 
            args=(df, C_inv, log_det_C),
            pool=pool,          # <--- This single argument enables parallelization
            backend=backend
        )
    
        print(f"Running MCMC for {nsteps} steps across {ncpu} cores...")
        sampler.run_mcmc(initial_pos, nsteps, progress=True)
    
    end_time = time.time()
    print(f"\nMCMC run complete and saved to disk.")
    print(f"Total time taken: {(end_time - start_time) / 60:.2f} minutes.")
#
# Out:
# Initializing MCMC Walkers...
# Detected 20 CPU cores. Setting up parallel pool...
# Running MCMC for 1000 steps across 18 cores...
#   3%|▎         | 34/1000 [00:28<13:59,  1.15it/s]Process ForkPoolWorker-11:
# Process ForkPoolWorker-9:
#   3%|▎         | 34/1000 [00:29<13:56,  1.16it/s]Process ForkPoolWorker-6:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-12:
# emcee: Exception while calling your likelihood function:emcee: Exception while calling your likelihood function:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-4:
# emcee: Exception while calling your likelihood function:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   params:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#    params:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   params:
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# [  0.35594     72.99300269 -19.24467825]
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   args:
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
# [  0.36008149  73.01213062 -19.24103119]
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   args:
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 385, in get
#     res = self._reader.recv_bytes()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/connection.py", line 225, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# [  0.33160398  73.00972288 -19.25639548]
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/connection.py", line 450, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/connection.py", line 415, in _recv
#     chunk = read(handle, to_read)
#   args:
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (                CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  \
# 0            2011fe        51  0.00122  0.00084  0.00122  0.00002  0.00082
# 1            2011fe        56  0.00122  0.00084  0.00122  0.00002  0.00082
# 2            2012cg        51  0.00256  0.00084  0.00256  0.00002  0.00144
# 3            2012cg        56  0.00256  0.00084  0.00256  0.00002  0.00144
# 4     1994DRichmond        50  0.00299  0.00084  0.00299  0.00004  0.00187
# ...             ...       ...      ...      ...      ...      ...      ...
# 1696       rutledge       106  1.61505  0.00545  1.61499  0.00500  1.61399
# 1697           geta       106  1.69706  0.04006  1.69702  0.04000  1.70000
# 1698          stone       106  1.80119  0.02014  1.80111  0.02000  1.80000
# 1699         wilson       106  1.91165  0.00263  1.91160  0.00100  1.91401
# 1700         colfax       106  2.26137  0.02018  2.26130  0.02000  2.26000
#
#       zHELERR  m_b_corr  m_b_corr_err_DIAG  ...  PKMJDERR  NDOF    FITCHI2  \
# 0     0.00002   9.74571           1.516210  ...    0.1071    36   26.88590
# 1     0.00002   9.80286           1.517230  ...    0.0579   101   88.30640
# 2     0.00002  11.47030           0.781906  ...    0.0278   165  233.50000
# 3     0.00002  11.49190           0.798612  ...    0.0667    55  100.12200
# 4     0.00004  11.52270           0.880798  ...    0.0522   146  109.83900
# ...       ...       ...                ...  ...       ...   ...        ...
# 1696  0.00500  25.90650           0.331927  ...    1.7256     8    2.92493
# 1697  0.04000  26.03330           0.379521  ...    1.8973    12    9.15387
# 1698  0.02000  26.23350           0.280685  ...    1.1631    11   11.69320
# 1699  0.00100  26.17030           0.357624  ...    1.4902     9    5.54378
# 1700  0.02000  26.92980           0.280011  ...    5.6828    13   10.19320
#
#        FITPROB  m_b_corr_err_RAW  m_b_corr_err_VPEC  biasCor_m_b  \
# 0     0.864470            0.0991             1.4960       0.0381
# 1     0.812220            0.0971             1.4960      -0.0252
# 2     0.000358            0.0399             0.7134       0.0545
# 3     0.000193            0.0931             0.7134       0.0622
# 4     0.988740            0.0567             0.6110       0.0650
# ...        ...               ...                ...          ...
# 1696  0.938980            0.2230             0.0106      -0.0203
# 1697  0.689730            0.3209             0.0748       0.2680
# 1698  0.387140            0.2370             0.0358      -0.0968
# 1699  0.784570            0.3168             0.0044      -0.3835
# 1700  0.678070            0.4455             0.0297      -0.5356
#
#       biasCorErr_m_b  biasCor_m_b_COVSCALE  biasCor_m_b_COVADD
# 0              0.005                 1.000               0.003
# 1              0.003                 1.000               0.004
# 2              0.019                 1.000               0.036
# 3              0.028                 1.000               0.040
# 4              0.009                 1.000               0.006
# ...              ...                   ...                 ...
# 1696           0.005                 1.000               0.002
# 1697           0.005                 0.633               0.000
# 1698           0.004                 0.641               0.000
# 1699           0.013                 0.604               0.000
# 1700           0.009                 0.164               0.000
#
# [1701 rows x 47 columns], array([[ 3.35405114e+01, -5.68645207e+00, -1.07870317e-01, ...,
#          1.44562349e-02,  1.73619092e-02,  6.56463462e-02],
#        [-5.68645207e+00,  3.26679149e+01,  6.27808976e-01, ...,
#          5.90524441e-02,  5.86751648e-02,  9.18237197e-02],
#        [-1.07870317e-01,  6.27808976e-01,  5.66302667e+01, ...,
#          4.04987270e-02,  6.08045796e-02,  1.44339360e-01],
#        ...,
#        [ 1.44562349e-02,  5.90524441e-02,  4.04987270e-02, ...,
#          2.64804296e+01, -2.56390502e-01, -5.18344050e-01],
#        [ 1.73619092e-02,  5.86751648e-02,  6.08045796e-02, ...,
#         -2.56390502e-01,  1.63294720e+01, -4.65796137e-01],
#        [ 6.56463462e-02,  9.18237197e-02,  1.44339360e-01, ...,
#         -5.18344050e-01, -4.65796137e-01,  2.87369713e+01]],
#       shape=(1701, 1701)), np.float64(-6400.748263993448))
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   kwargs:
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/synchronize.py", line 104, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# {}
#   exception:
# (                CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  \
# 0            2011fe        51  0.00122  0.00084  0.00122  0.00002  0.00082
# 1            2011fe        56  0.00122  0.00084  0.00122  0.00002  0.00082
# 2            2012cg        51  0.00256  0.00084  0.00256  0.00002  0.00144
# 3            2012cg        56  0.00256  0.00084  0.00256  0.00002  0.00144
# 4     1994DRichmond        50  0.00299  0.00084  0.00299  0.00004  0.00187
# ...             ...       ...      ...      ...      ...      ...      ...
# 1696       rutledge       106  1.61505  0.00545  1.61499  0.00500  1.61399
# 1697           geta       106  1.69706  0.04006  1.69702  0.04000  1.70000
# 1698          stone       106  1.80119  0.02014  1.80111  0.02000  1.80000
# 1699         wilson       106  1.91165  0.00263  1.91160  0.00100  1.91401
# 1700         colfax       106  2.26137  0.02018  2.26130  0.02000  2.26000
#
#       zHELERR  m_b_corr  m_b_corr_err_DIAG  ...  PKMJDERR  NDOF    FITCHI2  \
# 0     0.00002   9.74571           1.516210  ...    0.1071    36   26.88590
# 1     0.00002   9.80286           1.517230  ...    0.0579   101   88.30640
# 2     0.00002  11.47030           0.781906  ...    0.0278   165  233.50000
# 3     0.00002  11.49190           0.798612  ...    0.0667    55  100.12200
# 4     0.00004  11.52270           0.880798  ...    0.0522   146  109.83900
# ...       ...       ...                ...  ...       ...   ...        ...
# 1696  0.00500  25.90650           0.331927  ...    1.7256     8    2.92493
# 1697  0.04000  26.03330           0.379521  ...    1.8973    12    9.15387
# 1698  0.02000  26.23350           0.280685  ...    1.1631    11   11.69320
# 1699  0.00100  26.17030           0.357624  ...    1.4902     9    5.54378
# 1700  0.02000  26.92980           0.280011  ...    5.6828    13   10.19320
#
#        FITPROB  m_b_corr_err_RAW  m_b_corr_err_VPEC  biasCor_m_b  \
# 0     0.864470            0.0991             1.4960       0.0381
# 1     0.812220            0.0971             1.4960      -0.0252
# 2     0.000358            0.0399             0.7134       0.0545
# 3     0.000193            0.0931             0.7134       0.0622
# 4     0.988740            0.0567             0.6110       0.0650
# ...        ...               ...                ...          ...
# 1696  0.938980            0.2230             0.0106      -0.0203
# 1697  0.689730            0.3209             0.0748       0.2680
# 1698  0.387140            0.2370             0.0358      -0.0968
# 1699  0.784570            0.3168             0.0044      -0.3835
# 1700  0.678070            0.4455             0.0297      -0.5356
#
#       biasCorErr_m_b  biasCor_m_b_COVSCALE  biasCor_m_b_COVADD
# 0              0.005                 1.000               0.003
# 1              0.003                 1.000               0.004
# 2              0.019                 1.000               0.036
# 3              0.028                 1.000               0.040
# 4              0.009                 1.000               0.006
# ...              ...                   ...                 ...
# 1696           0.005                 1.000               0.002
# 1697           0.005                 0.633               0.000
# 1698           0.004                 0.641               0.000
# 1699           0.013                 0.604               0.000
# 1700           0.009                 0.164               0.000
#
# [1701 rows x 47 columns], array([[ 3.35405114e+01, -5.68645207e+00, -1.07870317e-01, ...,
#          1.44562349e-02,  1.73619092e-02,  6.56463462e-02],
#        [-5.68645207e+00,  3.26679149e+01,  6.27808976e-01, ...,
#          5.90524441e-02,  5.86751648e-02,  9.18237197e-02],
#        [-1.07870317e-01,  6.27808976e-01,  5.66302667e+01, ...,
#          4.04987270e-02,  6.08045796e-02,  1.44339360e-01],
#        ...,
#        [ 1.44562349e-02,  5.90524441e-02,  4.04987270e-02, ...,
#          2.64804296e+01, -2.56390502e-01, -5.18344050e-01],
#        [ 1.73619092e-02,  5.86751648e-02,  6.08045796e-02, ...,
#         -2.56390502e-01,  1.63294720e+01, -4.65796137e-01],
#        [ 6.56463462e-02,  9.18237197e-02,  1.44339360e-01, ...,
#         -5.18344050e-01, -4.65796137e-01,  2.87369713e+01]],
#       shape=(1701, 1701)), np.float64(-6400.748263993448))
#   kwargs: {}
# Traceback (most recent call last):
#   exception:
#   File "/home/rudranil/.local/lib/python3.14/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 33, in log_posterior
#     return lp + log_likelihood(params, data, C_inv, log_det_C)
#                 ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 16, in log_likelihood
#     delta = build_residual_vector(params, data)
#   File "/tmp/ipykernel_35576/4034811984.py", line 5, in build_residual_vector
#     for i, row in data.iterrows():
#                   ~~~~~~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/frame.py", line 1563, in iterrows
#     s = klass(v, index=columns, name=k).__finalize__(self)
#         ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/series.py", line 587, in __init__
#     data = sanitize_array(data, index, dtype, copy)
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/construction.py", line 604, in sanitize_array
#     subarr = maybe_infer_to_datetimelike(data)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/dtypes/cast.py", line 1200, in maybe_infer_to_datetimelike
#     return lib.maybe_convert_objects(  # type: ignore[return-value]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         value,
#         ^^^^^^
#     ...<5 lines>...
#         dtype_if_all_nat=np.dtype("M8[ns]"),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "pandas/_libs/lib.pyx", line 2560, in pandas._libs.lib.maybe_convert_objects
#   File "/home/rudranil/.local/lib/python3.14/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/numpy/_core/numeric.py", line 385, in full
#     a = empty(shape, dtype, order, device=device)
#   File "/tmp/ipykernel_35576/4034811984.py", line 33, in log_posterior
#     return lp + log_likelihood(params, data, C_inv, log_det_C)
#                 ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/tmp/ipykernel_35576/4034811984.py", line 16, in log_likelihood
#     delta = build_residual_vector(params, data)
# Process ForkPoolWorker-7:
#   File "/tmp/ipykernel_35576/4034811984.py", line 10, in build_residual_vector
#     m_b_th = model_cosmology(row['zHEL'], row['zCMB'], M_B, H_0, Omega_m)
#   File "/tmp/ipykernel_35576/1664658690.py", line 15, in model_cosmology
#     d_L_mpc = luminosity_distance_mpc(z_hel, z_cmb, H_0, Omega_m)
# Traceback (most recent call last):
#   File "/tmp/ipykernel_35576/1664658690.py", line 11, in luminosity_distance_mpc
#     integral, _ = quad(E_inverse, 0, z_cmb, args=(Omega_m,))
#                   ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 479, in quad
#     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#                    points)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 626, in _quad
#     return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_35576/1664658690.py", line 6, in E_inverse
#     def E_inverse(z, Omega_m):
#
#   File "/home/rudranil/.local/lib/python3.14/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 33, in log_posterior
#     return lp + log_likelihood(params, data, C_inv, log_det_C)
#                 ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# (                CID  IDSURVEY      zHD   zHDERR     zCMB  zCMBERR     zHEL  \
# 0            2011fe        51  0.00122  0.00084  0.00122  0.00002  0.00082
# 1            2011fe        56  0.00122  0.00084  0.00122  0.00002  0.00082
# 2            2012cg        51  0.00256  0.00084  0.00256  0.00002  0.00144
# 3            2012cg        56  0.00256  0.00084  0.00256  0.00002  0.00144
# 4     1994DRichmond        50  0.00299  0.00084  0.00299  0.00004  0.00187
# ...             ...       ...      ...      ...      ...      ...      ...
# 1696       rutledge       106  1.61505  0.00545  1.61499  0.00500  1.61399
# 1697           geta       106  1.69706  0.04006  1.69702  0.04000  1.70000
# 1698          stone       106  1.80119  0.02014  1.80111  0.02000  1.80000
# 1699         wilson       106  1.91165  0.00263  1.91160  0.00100  1.91401
# 1700         colfax       106  2.26137  0.02018  2.26130  0.02000  2.26000
#
#       zHELERR  m_b_corr  m_b_corr_err_DIAG  ...  PKMJDERR  NDOF    FITCHI2  \
# 0     0.00002   9.74571           1.516210  ...    0.1071    36   26.88590
# 1     0.00002   9.80286           1.517230  ...    0.0579   101   88.30640
# 2     0.00002  11.47030           0.781906  ...    0.0278   165  233.50000
# 3     0.00002  11.49190           0.798612  ...    0.0667    55  100.12200
# 4     0.00004  11.52270           0.880798  ...    0.0522   146  109.83900
# ...       ...       ...                ...  ...       ...   ...        ...
# 1696  0.00500  25.90650           0.331927  ...    1.7256     8    2.92493
# 1697  0.04000  26.03330           0.379521  ...    1.8973    12    9.15387
# 1698  0.02000  26.23350           0.280685  ...    1.1631    11   11.69320
# 1699  0.00100  26.17030           0.357624  ...    1.4902     9    5.54378
# 1700  0.02000  26.92980           0.280011  ...    5.6828    13   10.19320
#
#        FITPROB  m_b_corr_err_RAW  m_b_corr_err_VPEC  biasCor_m_b  \
# 0     0.864470            0.0991             1.4960       0.0381
# 1     0.812220            0.0971             1.4960      -0.0252
# 2     0.000358            0.0399             0.7134       0.0545
# 3     0.000193            0.0931             0.7134       0.0622
# 4     0.988740            0.0567             0.6110       0.0650
# ...        ...               ...                ...          ...
# 1696  0.938980            0.2230             0.0106      -0.0203
# 1697  0.689730            0.3209             0.0748       0.2680
# 1698  0.387140            0.2370             0.0358      -0.0968
# 1699  0.784570            0.3168             0.0044      -0.3835
# 1700  0.678070            0.4455             0.0297      -0.5356
#
#       biasCorErr_m_b  biasCor_m_b_COVSCALE  biasCor_m_b_COVADD
# 0              0.005                 1.000               0.003
# 1              0.003                 1.000               0.004
# 2              0.019                 1.000               0.036
# 3              0.028                 1.000               0.040
# 4              0.009                 1.000               0.006
# ...              ...                   ...                 ...
# 1696           0.005                 1.000               0.002
# 1697           0.005                 0.633               0.000
# 1698           0.004                 0.641               0.000
# 1699           0.013                 0.604               0.000
# 1700           0.009                 0.164               0.000
#
# [1701 rows x 47 columns], array([[ 3.35405114e+01, -5.68645207e+00, -1.07870317e-01, ...,
#          1.44562349e-02,  1.73619092e-02,  6.56463462e-02],
#        [-5.68645207e+00,  3.26679149e+01,  6.27808976e-01, ...,
#          5.90524441e-02,  5.86751648e-02,  9.18237197e-02],
#        [-1.07870317e-01,  6.27808976e-01,  5.66302667e+01, ...,
#          4.04987270e-02,  6.08045796e-02,  1.44339360e-01],
#        ...,
#        [ 1.44562349e-02,  5.90524441e-02,  4.04987270e-02, ...,
#          2.64804296e+01, -2.56390502e-01, -5.18344050e-01],
#        [ 1.73619092e-02,  5.86751648e-02,  6.08045796e-02, ...,
#         -2.56390502e-01,  1.63294720e+01, -4.65796137e-01],
#        [ 6.56463462e-02,  9.18237197e-02,  1.44339360e-01, ...,
#         -5.18344050e-01, -4.65796137e-01,  2.87369713e+01]],
#       shape=(1701, 1701)), np.float64(-6400.748263993448))
#   File "/tmp/ipykernel_35576/4034811984.py", line 16, in log_likelihood
#     delta = build_residual_vector(params, data)
# Process ForkPoolWorker-3:
#   File "/tmp/ipykernel_35576/4034811984.py", line 5, in build_residual_vector
#     for i, row in data.iterrows():
#                   ~~~~~~~~~~~~~^^
#   kwargs:
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/frame.py", line 1563, in iterrows
#     s = klass(v, index=columns, name=k).__finalize__(self)
#         ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/series.py", line 587, in __init__
#     data = sanitize_array(data, index, dtype, copy)
# {}
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/construction.py", line 604, in sanitize_array
#     subarr = maybe_infer_to_datetimelike(data)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/pandas/core/dtypes/cast.py", line 1200, in maybe_infer_to_datetimelike
#     return lib.maybe_convert_objects(  # type: ignore[return-value]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         value,
#         ^^^^^^
#     ...<5 lines>...
#         dtype_if_all_nat=np.dtype("M8[ns]"),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   exception:
#   File "pandas/_libs/lib.pyx", line 2560, in pandas._libs.lib.maybe_convert_objects
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/numpy/_core/numeric.py", line 385, in full
#     a = empty(shape, dtype, order, device=device)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/rudranil/.local/lib/python3.14/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 33, in log_posterior
#     return lp + log_likelihood(params, data, C_inv, log_det_C)
#                 ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 16, in log_likelihood
#     delta = build_residual_vector(params, data)
#   File "/tmp/ipykernel_35576/4034811984.py", line 33, in log_posterior
#     return lp + log_likelihood(params, data, C_inv, log_det_C)
#                 ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 10, in build_residual_vector
#     m_b_th = model_cosmology(row['zHEL'], row['zCMB'], M_B, H_0, Omega_m)
#   File "/tmp/ipykernel_35576/1664658690.py", line 15, in model_cosmology
#     d_L_mpc = luminosity_distance_mpc(z_hel, z_cmb, H_0, Omega_m)
#   File "/tmp/ipykernel_35576/4034811984.py", line 16, in log_likelihood
#     delta = build_residual_vector(params, data)
#   File "/tmp/ipykernel_35576/1664658690.py", line 11, in luminosity_distance_mpc
#     integral, _ = quad(E_inverse, 0, z_cmb, args=(Omega_m,))
#                   ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 479, in quad
#     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#                    points)
#   File "/tmp/ipykernel_35576/4034811984.py", line 10, in build_residual_vector
#     m_b_th = model_cosmology(row['zHEL'], row['zCMB'], M_B, H_0, Omega_m)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 626, in _quad
#     return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/1664658690.py", line 15, in model_cosmology
#     d_L_mpc = luminosity_distance_mpc(z_hel, z_cmb, H_0, Omega_m)
#   File "/tmp/ipykernel_35576/1664658690.py", line 11, in luminosity_distance_mpc
#     integral, _ = quad(E_inverse, 0, z_cmb, args=(Omega_m,))
#                   ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/1664658690.py", line 6, in E_inverse
#     def E_inverse(z, Omega_m):
#
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 479, in quad
#     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#                    points)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 626, in _quad
#     return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/tmp/ipykernel_35576/1664658690.py", line 6, in E_inverse
#     def E_inverse(z, Omega_m):
#
# Process ForkPoolWorker-2:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/rudranil/.local/lib/python3.14/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 33, in log_posterior
#     return lp + log_likelihood(params, data, C_inv, log_det_C)
#                 ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/4034811984.py", line 16, in log_likelihood
#     delta = build_residual_vector(params, data)
#   File "/tmp/ipykernel_35576/4034811984.py", line 10, in build_residual_vector
#     m_b_th = model_cosmology(row['zHEL'], row['zCMB'], M_B, H_0, Omega_m)
#   File "/tmp/ipykernel_35576/1664658690.py", line 15, in model_cosmology
#     d_L_mpc = luminosity_distance_mpc(z_hel, z_cmb, H_0, Omega_m)
#   File "/tmp/ipykernel_35576/1664658690.py", line 11, in luminosity_distance_mpc
#     integral, _ = quad(E_inverse, 0, z_cmb, args=(Omega_m,))
#                   ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 479, in quad
#     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#                    points)
#   File "/home/rudranil/.local/lib/python3.14/site-packages/scipy/integrate/_quadpack_py.py", line 626, in _quad
#     return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35576/1664658690.py", line 6, in E_inverse
#     def E_inverse(z, Omega_m):
#
# KeyboardInterrupt

# %% [markdown]
# # Discard Burn-in and Compute Posterior

# %%
# We discard the first 300 steps of each walker as "burn-in" 
# (time taken for walkers to forget their initial positions and reach the true posterior)
discard_steps = 300
thin_steps = 15 # Thinning to reduce autocorrelation

# Flatten the chain into a single 2D array of samples
flat_samples = sampler.get_chain(discard=discard_steps, thin=thin_steps, flat=True)

print(f"Total number of useful samples generated: {len(flat_samples)}")

# Calculate the median and 16th/84th percentiles (1-sigma intervals)
labels = [r"\Omega_m", r"H_0", r"M_B"]
results = {}

print("\n--- Parameter Constraints (Median ± 1-sigma) ---")
for i in range(ndim):
    mcmc_samples = flat_samples[:, i]
    median = np.percentile(mcmc_samples, 50)
    lower_error = median - np.percentile(mcmc_samples, 16)
    upper_error = np.percentile(mcmc_samples, 84) - median
    
    results[labels[i]] = (median, lower_error, upper_error)
    print(f"{labels[i]}: {median:.4f} +{upper_error:.4f} / -{lower_error:.4f}")

# %%
print("Generating corner plot...")
fig = corner.corner(
    flat_samples, 
    labels=[r"$\Omega_m$", r"$H_0$", r"$M_B$"], 
    truths=[results[r"\Omega_m"][0], results[r"H_0"][0], results[r"M_B"][0]],
    quantiles=[0.16, 0.5, 0.84],
    show_titles=True, 
    title_kwargs={"fontsize": 12}
)
